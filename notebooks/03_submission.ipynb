# %% [markdown]
# # 03 予測と提出ファイル作成
#
# **目的**: テストデータの予測結果を CSV に出力する。
#
# ---
#
# ## このノートブックでやること
#
# 1. `02` で保存したモデルを読み込む
# 2. テストデータを読み込む
# 3. **学習時と同じ前処理** を適用する
# 4. 予測して `out/submission.csv` に保存する
#
# ---
#
# ## ヒント
#
# ### 前提
# - 先に `02_baseline_model.ipynb` を実行し、`models/baseline_model.joblib` を作っておく
#
# ### 読み込み
# - `from analysis_titanic.load_data import load_test`
# - `from analysis_titanic.paths import MODELS_DIR, OUT_DIR, SAMPLE_SUBMIT_CSV`
# - `joblib.load(MODELS_DIR / "baseline_model.joblib")`
#
# ### 前処理
# - **02 と同じ関数・同じ値** を使う（ここがズレると予測がおかしくなる）
# - 学習時に存在しなかった列が出たら 0 で埋める、など列を揃える
#
# ### 予測
# - `model.predict(X_test)` で 0/1 の予測値が得られる
#
# ### 提出ファイル
# - 形式は `data/sample_submit.csv` に合わせる
# - 2列: `id`, `survived`（ヘッダーなし）
# - 保存先: `out/submission.csv`
#
# ```python
# # 保存例
# submission.to_csv(path, index=False, header=False)
# ```
#
# ### 確認（任意）
# - 行数が `sample_submit.csv` と同じか
# - `id` の並びが一致しているか
#
# ---
#
# **お疲れさまでした！** EDA → モデル → 提出 の流れが一通り完了。

# %%
# ここから自分でコードを書いていく
# 例: joblib.load → load_test → 前処理 → predict → to_csv
